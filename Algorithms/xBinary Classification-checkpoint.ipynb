# %% [markdown]
# code come from
#
# https://www.kaggle.com/code/laihaochan/exercise-binary-classification/edit

# %%
# Setup plotting
import matplotlib.pyplot as plt
#plt.style.use('seaborn-whitegrid')
import seaborn as sns

# Use seaborn API for styling
sns.set(style='whitegrid', font_scale=1.5)


# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *

# %%
#First, load the Hotel Cancellations dataset.
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# ### Define Model
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()

# %% [raw]
# Correct

# %%
q_1.hint()
q_1.solution()

# %% [raw]
# Hint: Your answer should look something like:
#
# model = keras.Sequential([
#     # Batch Normalization
#
#     # Dense
#     # Batch Normalization
#     # Dropout
#
#     # Dense
#     # Batch Normalization
#     # Dropout
#
#     # Dense
# ])
# Solution:
#
#
# from tensorflow import keras
# from tensorflow.keras import layers
#
# model = keras.Sequential([
#     layers.BatchNormalization(input_shape=input_shape),
#     layers.Dense(256, activation='relu'),
#     layers.BatchNormalization(),
#     layers.Dropout(0.3),
#     layers.Dense(256, activation='relu'),
#     layers.BatchNormalization(),
#     layers.Dropout(0.3),
#     layers.Dense(1, activation='sigmoid'),
# ])
# q_1.assert_check_passed()

# %% [markdown]
# ### Add Optimizer, Loss, and Metric
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# Check your answer
q_2.check()

# %% [raw]
# Correct

# %%
# Lines below will give you a hint or solution code
q_2.hint()
q_2.solution()

# %% [raw]
# Hint: Your code should look something like:
#
# model.compile(
# optimizer=____,
# loss=____,
# metrics=____,
# )
# Solution:
#
#
# model.compile(
#     optimizer='adam',
#     loss='binary_crossentropy',
#     metrics=['binary_accuracy'],
# )

# %%
#run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")

# %% [raw]
# Epoch 1/200
# 175/175 [==============================] - 6s 23ms/step - loss: 0.4793 - binary_accuracy: 0.7752 - val_loss: 0.4314 - val_binary_accuracy: 0.7930
# Epoch 2/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.4217 - binary_accuracy: 0.8008 - val_loss: 0.4008 - val_binary_accuracy: 0.8132
# Epoch 3/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.4089 - binary_accuracy: 0.8087 - val_loss: 0.3943 - val_binary_accuracy: 0.8160
# Epoch 4/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.4029 - binary_accuracy: 0.8115 - val_loss: 0.3912 - val_binary_accuracy: 0.8174
# Epoch 5/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3974 - binary_accuracy: 0.8138 - val_loss: 0.3876 - val_binary_accuracy: 0.8214
# Epoch 6/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3912 - binary_accuracy: 0.8174 - val_loss: 0.3848 - val_binary_accuracy: 0.8212
# Epoch 7/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3881 - binary_accuracy: 0.8192 - val_loss: 0.3815 - val_binary_accuracy: 0.8237
# Epoch 8/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3855 - binary_accuracy: 0.8206 - val_loss: 0.3826 - val_binary_accuracy: 0.8244
# Epoch 9/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3814 - binary_accuracy: 0.8226 - val_loss: 0.3758 - val_binary_accuracy: 0.8272
# Epoch 10/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3781 - binary_accuracy: 0.8246 - val_loss: 0.3739 - val_binary_accuracy: 0.8289
# Epoch 11/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3751 - binary_accuracy: 0.8264 - val_loss: 0.3704 - val_binary_accuracy: 0.8300
# Epoch 12/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3748 - binary_accuracy: 0.8272 - val_loss: 0.3677 - val_binary_accuracy: 0.8312
# Epoch 13/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3704 - binary_accuracy: 0.8287 - val_loss: 0.3650 - val_binary_accuracy: 0.8320
# Epoch 14/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3702 - binary_accuracy: 0.8300 - val_loss: 0.3658 - val_binary_accuracy: 0.8317
# Epoch 15/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3669 - binary_accuracy: 0.8309 - val_loss: 0.3636 - val_binary_accuracy: 0.8353
# Epoch 16/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3651 - binary_accuracy: 0.8312 - val_loss: 0.3615 - val_binary_accuracy: 0.8322
# Epoch 17/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3642 - binary_accuracy: 0.8322 - val_loss: 0.3608 - val_binary_accuracy: 0.8347
# Epoch 18/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3625 - binary_accuracy: 0.8335 - val_loss: 0.3591 - val_binary_accuracy: 0.8359
# Epoch 19/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3599 - binary_accuracy: 0.8330 - val_loss: 0.3648 - val_binary_accuracy: 0.8306
# Epoch 20/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3594 - binary_accuracy: 0.8339 - val_loss: 0.3580 - val_binary_accuracy: 0.8358
# Epoch 21/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3577 - binary_accuracy: 0.8344 - val_loss: 0.3574 - val_binary_accuracy: 0.8364
# Epoch 22/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3562 - binary_accuracy: 0.8350 - val_loss: 0.3580 - val_binary_accuracy: 0.8372
# Epoch 23/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3555 - binary_accuracy: 0.8358 - val_loss: 0.3573 - val_binary_accuracy: 0.8368
# Epoch 24/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3530 - binary_accuracy: 0.8368 - val_loss: 0.3552 - val_binary_accuracy: 0.8367
# Epoch 25/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3531 - binary_accuracy: 0.8375 - val_loss: 0.3554 - val_binary_accuracy: 0.8361
# Epoch 26/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3516 - binary_accuracy: 0.8373 - val_loss: 0.3558 - val_binary_accuracy: 0.8354
# Epoch 27/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3496 - binary_accuracy: 0.8392 - val_loss: 0.3551 - val_binary_accuracy: 0.8366
# Epoch 28/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3500 - binary_accuracy: 0.8377 - val_loss: 0.3546 - val_binary_accuracy: 0.8379
# Epoch 29/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3483 - binary_accuracy: 0.8392 - val_loss: 0.3521 - val_binary_accuracy: 0.8383
# Epoch 30/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3477 - binary_accuracy: 0.8401 - val_loss: 0.3532 - val_binary_accuracy: 0.8366
# Epoch 31/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3467 - binary_accuracy: 0.8404 - val_loss: 0.3517 - val_binary_accuracy: 0.8394
# Epoch 32/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3460 - binary_accuracy: 0.8403 - val_loss: 0.3528 - val_binary_accuracy: 0.8373
# Epoch 33/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3438 - binary_accuracy: 0.8412 - val_loss: 0.3515 - val_binary_accuracy: 0.8376
# Epoch 34/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3445 - binary_accuracy: 0.8415 - val_loss: 0.3502 - val_binary_accuracy: 0.8379
# Epoch 35/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3434 - binary_accuracy: 0.8415 - val_loss: 0.3503 - val_binary_accuracy: 0.8388
# Epoch 36/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3429 - binary_accuracy: 0.8414 - val_loss: 0.3496 - val_binary_accuracy: 0.8388
# Epoch 37/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3424 - binary_accuracy: 0.8422 - val_loss: 0.3499 - val_binary_accuracy: 0.8398
# Epoch 38/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3412 - binary_accuracy: 0.8431 - val_loss: 0.3496 - val_binary_accuracy: 0.8386
# Epoch 39/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3398 - binary_accuracy: 0.8426 - val_loss: 0.3493 - val_binary_accuracy: 0.8390
#
#
# <Axes: title={'center': 'Accuracy'}>
# Cross-entropy_picture
# Accuracy_picture

# %% [markdown]
# ### Train and Evaluate
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()

# %% [raw]
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!
